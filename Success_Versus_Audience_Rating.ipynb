# %%
# Dependencies
import pandas as pd
from pathlib import Path

# Filtered Dataset
filtered_data = Path("Datasets/filtered_data.csv")
filtered_df = pd.read_csv(filtered_data)
filtered_df.head()
# Out:
#                           Movie Name  Vote Average  Vote Count  \
# 0                       Mother's Day           6.0          94
# 1  Spider-Man: Into the Spider-Verse           8.4       13081
# 2    Transformers: Age of Extinction           5.9        7359
# 3      Transformers: The Last Knight           6.1        5548
# 4     Guardians of the Galaxy Vol. 2           7.6       19898
#
#                                 Production Companies     Revenue  \
# 0                                   ['Akson Studio']           0
# 1  ['Columbia Pictures', 'Lord Miller', 'Pascal P...   375464627
# 2  ['di Bonaventura Pictures', 'Tom DeSanto/Don M...  1104054072
# 3  ['Paramount', 'di Bonaventura Pictures', 'Ian ...   605425157
# 4                                 ['Marvel Studios']   863756051
#
#    Year of Release  Movie Rating     Votes        Gross  \
# 0           2016.0           5.6   38894.0   32460000.0
# 1           2018.0           8.4  632177.0  190240000.0
# ...

# %%
audience_df = filtered_df[["Movie Name", "Year of Release", "Movie Rating", "Votes", "Certification"]]
audience_df.head()
# Out:
#                           Movie Name  Year of Release  Movie Rating     Votes  \
# 0                       Mother's Day           2016.0           5.6   38894.0
# 1  Spider-Man: Into the Spider-Verse           2018.0           8.4  632177.0
# 2    Transformers: Age of Extinction           2014.0           5.6  326960.0
# 3      Transformers: The Last Knight           2017.0           5.2  164230.0
# 4     Guardians of the Galaxy Vol. 2           2017.0           7.6  736895.0
#
#   Certification
# 0         PG-13
# 1            PG
# 2         PG-13
# 3         PG-13
# 4         PG-13

# %%
# List of Certifications
audience_df["Certification"].value_counts()
# Out:
# Certification
# R            624
# PG-13        501
# PG           189
# Not Rated     50
# G             12
# TV-MA          4
# TV-PG          1
# TV-14          1
# NC-17          1
# Unrated        1
# Name: count, dtype: int64

# %%
# Group by certification and movie rating
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Group by certification and movie rating
# ----> 2 audience_df = audience_df.groupby(["Movie Rating", "Certification"]).sum()
#
# File E:\Anaconda3\envs\dev\lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'
