# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# CSV files
dataset_one = Path("Datasets/10000_movies(1915-2023).csv")
dataset_two = Path("Datasets/top_1000_popular_movies_tmdb.csv")

# %%
# Convert to dataframes
one_df = pd.read_csv(dataset_one)
two_df = pd.read_csv(dataset_two, lineterminator='\n')

# %%
one_df
# Out:
#       Unnamed: 0                           Movie Name  Year of Release  \
# 0              0             The Shawshank Redemption             1994
# 1              1                        The Godfather             1972
# 2              2  Ramayana: The Legend of Prince Rama             1993
# 3              3                      The Chaos Class             1975
# 4              4                      The Dark Knight             2008
# ...          ...                                  ...              ...
# 9995        9995                        Golmaal Again             2017
# 9996        9996                        Not to Forget             2021
# 9997        9997                          Housefull 3             2016
# 9998        9998                          A.I. Rising             2018
# 9999        9999                         The Last Boy             2019
#
#       Run Time in minutes  Movie Rating    Votes  MetaScore        Gross  \
# 0                     142           9.3  2804443       82.0   28340000.0
# 1                     175           9.2  1954174      100.0  134970000.0
# 2                     135           9.2    12995        NaN          NaN
# 3                      87           9.2    42231        NaN          NaN
# 4                     152           9.0  2786129       84.0  534860000.0
# ...                   ...           ...      ...        ...          ...
# 9995                  140           4.9    10183        NaN    1010000.0
# 9996                   84           4.9    11191        NaN          NaN
# 9997                  140           4.9    10308        NaN    1160000.0
# 9998                   85           4.9    11187        NaN          NaN
# 9999                   87           4.9    10324        NaN          NaN
#
#                                        Genre Certification  \
# 0                                  ['Drama']             R
# 1                        ['Crime', ' Drama']             R
# 2     ['Animation', ' Action', ' Adventure']            PG
# 3                       ['Comedy', ' Drama']           NaN
# 4             ['Action', ' Crime', ' Drama']         PG-13
# ...                                      ...           ...
# 9995       ['Action', ' Comedy', ' Fantasy']     Not Rated
# 9996                               ['Drama']           NaN
# 9997       ['Action', ' Comedy', ' Romance']     Not Rated
# 9998        ['Drama', ' Romance', ' Sci-Fi']             R
# 9999      ['Fantasy', ' Mystery', ' Sci-Fi']           NaN
#
#                                         Director  \
# 0                             ['Frank Darabont']
# 1                       ['Francis Ford Coppola']
# 2     ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski']
# 3                              ['Ertem Egilmez']
# 4                          ['Christopher Nolan']
# ...                                          ...
# 9995                            ['Rohit Shetty']
# 9996                          ['Valerio Zanoli']
# 9997                   ['Sajid', 'Farhad Samji']
# 9998                           ['Lazar Bodroza']
# 9999                           ['Perry Bhandal']
#
#                                                   Stars  \
# 0     ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...
# 1     ['Marlon Brando', 'Al Pacino', 'James Caan', '...
# 2     ['Arun Govil', 'Nikhil Kapoor', 'Edie Mirman',...
# 3     ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...
# 4     ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# ...                                                 ...
# 9995  ['Ajay Devgn', 'Arshad Warsi', 'Tabu', 'Shreya...
# 9996  ['Karen Grassle', 'Louis Gossett Jr.', "Tatum ...
# 9997  ['Akshay Kumar', 'Abhishek Bachchan', 'Riteish...
# 9998  ['Sebastian Cavazza', 'Stoya', 'Marusa Majer',...
# 9999  ['Luke Goss', 'Flynn Allen', 'Peter Guinness',...
#
#                                             Description
# 0     ['Over', 'the', 'course', 'of', 'several', 'ye...
# 1     ['Don', 'Vito', 'Corleone,', 'head', 'of', 'a'...
# 2     ['An', 'anime', 'adaptation', 'of', 'the', 'Hi...
# 3     ['Lazy,', 'uneducated', 'students', 'share', '...
# 4     ['When', 'the', 'menace', 'known', 'as', 'the'...
# ...                                                 ...
# 9995  ['The', 'gang', 'encounters', 'with', 'some', ...
# 9996  ['After', 'a', 'lifetime', 'of', 'scams,', 'a'...
# 9997  ['A', 'father', "doesn't", 'want', 'his', 'thr...
# 9998  ['An', 'intimate', 'relationship', 'between', ...
# 9999  ['With', 'the', "world's", 'end', 'imminent,',...
#
# [10000 rows x 13 columns]

# %%
# Delete unneeded columns
del one_df["Unnamed: 0"]
del one_df["Stars"]
del one_df["Run Time in minutes"]
del one_df["Description"]
del one_df["MetaScore"]
one_df
# Out:
#                                Movie Name  Year of Release  Movie Rating  \
# 0                The Shawshank Redemption             1994           9.3
# 1                           The Godfather             1972           9.2
# 2     Ramayana: The Legend of Prince Rama             1993           9.2
# 3                         The Chaos Class             1975           9.2
# 4                         The Dark Knight             2008           9.0
# ...                                   ...              ...           ...
# 9995                        Golmaal Again             2017           4.9
# 9996                        Not to Forget             2021           4.9
# 9997                          Housefull 3             2016           4.9
# 9998                          A.I. Rising             2018           4.9
# 9999                         The Last Boy             2019           4.9
#
#         Votes        Gross                                   Genre  \
# 0     2804443   28340000.0                               ['Drama']
# 1     1954174  134970000.0                     ['Crime', ' Drama']
# 2       12995          NaN  ['Animation', ' Action', ' Adventure']
# 3       42231          NaN                    ['Comedy', ' Drama']
# 4     2786129  534860000.0          ['Action', ' Crime', ' Drama']
# ...       ...          ...                                     ...
# 9995    10183    1010000.0       ['Action', ' Comedy', ' Fantasy']
# 9996    11191          NaN                               ['Drama']
# 9997    10308    1160000.0       ['Action', ' Comedy', ' Romance']
# 9998    11187          NaN        ['Drama', ' Romance', ' Sci-Fi']
# 9999    10324          NaN      ['Fantasy', ' Mystery', ' Sci-Fi']
#
#      Certification                                    Director
# 0                R                          ['Frank Darabont']
# 1                R                    ['Francis Ford Coppola']
# 2               PG  ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski']
# 3              NaN                           ['Ertem Egilmez']
# 4            PG-13                       ['Christopher Nolan']
# ...            ...                                         ...
# 9995     Not Rated                            ['Rohit Shetty']
# 9996           NaN                          ['Valerio Zanoli']
# 9997     Not Rated                   ['Sajid', 'Farhad Samji']
# 9998             R                           ['Lazar Bodroza']
# 9999           NaN                           ['Perry Bhandal']
#
# [10000 rows x 8 columns]

# %%
two_df
# Out:
#       Unnamed: 0      id                                title release_date  \
# 0              0  385687                               Fast X   2023-05-17
# 1              1  603692                 John Wick: Chapter 4   2023-03-22
# 2              2  502356          The Super Mario Bros. Movie   2023-04-05
# 3              3  569094  Spider-Man: Across the Spider-Verse   2023-05-31
# 4              4  536437                             Hypnotic   2023-05-11
# ...          ...     ...                                  ...          ...
# 9995        9995   33142                                Vivah   2006-11-10
# 9996        9996    9442            Dead Men Don't Wear Plaid   1982-05-21
# 9997        9997   28774                            Communion   1989-11-10
# 9998        9998   11121                                 Tess   1979-10-06
# 9999        9999  272692       The Possession of Michael King   2014-08-14
#
#                                                  genres original_language  \
# 0                       ['Action', 'Crime', 'Thriller']           English
# 1                       ['Action', 'Thriller', 'Crime']           English
# 2     ['Animation', 'Family', 'Adventure', 'Fantasy'...           English
# 3     ['Action', 'Adventure', 'Animation', 'Science ...           English
# 4            ['Mystery', 'Thriller', 'Science Fiction']           English
# ...                                                 ...               ...
# 9995                               ['Romance', 'Drama']             Hindi
# 9996                              ['Comedy', 'Mystery']           English
# 9997  ['Drama', 'Horror', 'Science Fiction', 'Thrill...           English
# 9998                               ['Drama', 'Romance']           English
# 9999                                         ['Horror']           English
#
#       vote_average  vote_count  popularity  \
# 0              7.4        1347    8363.473
# 1              7.9        2896    4210.313
# 2              7.8        4628    3394.458
# 3              8.8        1160    2859.047
# 4              6.5         154    2654.854
# ...            ...         ...         ...
# 9995           6.4          70      12.301
# 9996           6.6         324      12.301
# 9997           5.3         147      12.300
# 9998           7.0         283      12.300
# 9999           6.1         346      12.297
#
#                                                overview     budget  \
# 0     Over many missions and against impossible odds...  340000000
# 1     With the price on his head ever increasing, Jo...   90000000
# 2     While working underground to fix a water main,...  100000000
# 3     After reuniting with Gwen Stacy, Brooklyn’s fu...  100000000
# 4     A detective becomes entangled in a mystery inv...   70000000
# ...                                                 ...        ...
# 9995  Poonam, a traditionally brought-up young woman...          0
# 9996  Juliet Forrest is convinced that the reported ...    9000000
# 9997  A novelist's wife and son see him changed by a...    5000000
# 9998  A strong-willed peasant girl is sent by her fa...   12000000
# 9999  The film tells the story of documentary filmma...          0
#
#                                    production_companies     revenue  runtime  \
# 0     ['Universal Pictures', 'Original Film', 'One R...   652000000      142
# 1     ['Thunder Road', '87Eleven', 'Summit Entertain...   431769198      170
# 2     ['Universal Pictures', 'Illumination', 'Ninten...  1308766975       92
# 3     ['Columbia Pictures', 'Sony Pictures Animation...   313522201      140
# 4     ['Studio 8', 'Solstice Productions', 'Ingeniou...           0       94
# ...                                                 ...         ...      ...
# 9995                            ['Rajshri Productions']     4000000      175
# 9996       ['Universal Pictures', 'Aspen Film Society']    18196170       89
# 9997  ['The Picture Property Company', 'Allied Visio...     1919653      103
# 9998  ['Renn Productions', 'Timothy Burrill Producti...    20101247      186
# 9999           ['Quickfire Films', 'Gold Circle Films']     2405143       83
#
#                                                 tagline
# 0                           The end of the road begins.
# 1                             No way back, one way out.
# 2                                                   NaN
# 3               It's how you wear the mask that matters
# 4                               Control is an illusion.
# ...                                                 ...
# 9995                           Marriage isn't a game...
# 9996                Laugh...or I’ll blow your lips off!
# 9997  The true story of one man's terrifying journey...
# 9998  She was born into a world where they called it...
# 9999     If you invite it in, it will never let you go.
#
# [10000 rows x 15 columns]

# %%
# Delete unneeded columns
del two_df["Unnamed: 0"]
del two_df["id"]
del two_df["tagline"]
del two_df["release_date"]
del two_df["original_language"]
del two_df["popularity"]
del two_df["overview"]
del two_df["runtime"]
two_df
# Out:
#                                     title  \
# 0                                  Fast X
# 1                    John Wick: Chapter 4
# 2             The Super Mario Bros. Movie
# 3     Spider-Man: Across the Spider-Verse
# 4                                Hypnotic
# ...                                   ...
# 9995                                Vivah
# 9996            Dead Men Don't Wear Plaid
# 9997                            Communion
# 9998                                 Tess
# 9999       The Possession of Michael King
#
#                                                  genres  vote_average  \
# 0                       ['Action', 'Crime', 'Thriller']           7.4
# 1                       ['Action', 'Thriller', 'Crime']           7.9
# 2     ['Animation', 'Family', 'Adventure', 'Fantasy'...           7.8
# 3     ['Action', 'Adventure', 'Animation', 'Science ...           8.8
# 4            ['Mystery', 'Thriller', 'Science Fiction']           6.5
# ...                                                 ...           ...
# 9995                               ['Romance', 'Drama']           6.4
# 9996                              ['Comedy', 'Mystery']           6.6
# 9997  ['Drama', 'Horror', 'Science Fiction', 'Thrill...           5.3
# 9998                               ['Drama', 'Romance']           7.0
# 9999                                         ['Horror']           6.1
#
#       vote_count     budget  \
# 0           1347  340000000
# 1           2896   90000000
# 2           4628  100000000
# 3           1160  100000000
# 4            154   70000000
# ...          ...        ...
# 9995          70          0
# 9996         324    9000000
# 9997         147    5000000
# 9998         283   12000000
# 9999         346          0
#
#                                    production_companies     revenue
# 0     ['Universal Pictures', 'Original Film', 'One R...   652000000
# 1     ['Thunder Road', '87Eleven', 'Summit Entertain...   431769198
# 2     ['Universal Pictures', 'Illumination', 'Ninten...  1308766975
# 3     ['Columbia Pictures', 'Sony Pictures Animation...   313522201
# 4     ['Studio 8', 'Solstice Productions', 'Ingeniou...           0
# ...                                                 ...         ...
# 9995                            ['Rajshri Productions']     4000000
# 9996       ['Universal Pictures', 'Aspen Film Society']    18196170
# 9997  ['The Picture Property Company', 'Allied Visio...     1919653
# 9998  ['Renn Productions', 'Timothy Burrill Producti...    20101247
# 9999           ['Quickfire Films', 'Gold Circle Films']     2405143
#
# [10000 rows x 7 columns]

# %%
# Rename columns for merging
two_df = two_df.rename(columns={"title": "Movie Name"})
two_df
# Out:
#                                Movie Name  \
# 0                                  Fast X
# 1                    John Wick: Chapter 4
# 2             The Super Mario Bros. Movie
# 3     Spider-Man: Across the Spider-Verse
# 4                                Hypnotic
# ...                                   ...
# 9995                                Vivah
# 9996            Dead Men Don't Wear Plaid
# 9997                            Communion
# 9998                                 Tess
# 9999       The Possession of Michael King
#
#                                                  genres  vote_average  \
# 0                       ['Action', 'Crime', 'Thriller']           7.4
# 1                       ['Action', 'Thriller', 'Crime']           7.9
# 2     ['Animation', 'Family', 'Adventure', 'Fantasy'...           7.8
# 3     ['Action', 'Adventure', 'Animation', 'Science ...           8.8
# 4            ['Mystery', 'Thriller', 'Science Fiction']           6.5
# ...                                                 ...           ...
# 9995                               ['Romance', 'Drama']           6.4
# 9996                              ['Comedy', 'Mystery']           6.6
# 9997  ['Drama', 'Horror', 'Science Fiction', 'Thrill...           5.3
# 9998                               ['Drama', 'Romance']           7.0
# 9999                                         ['Horror']           6.1
#
#       vote_count     budget  \
# 0           1347  340000000
# 1           2896   90000000
# 2           4628  100000000
# 3           1160  100000000
# 4            154   70000000
# ...          ...        ...
# 9995          70          0
# 9996         324    9000000
# 9997         147    5000000
# 9998         283   12000000
# 9999         346          0
#
#                                    production_companies     revenue
# 0     ['Universal Pictures', 'Original Film', 'One R...   652000000
# 1     ['Thunder Road', '87Eleven', 'Summit Entertain...   431769198
# 2     ['Universal Pictures', 'Illumination', 'Ninten...  1308766975
# 3     ['Columbia Pictures', 'Sony Pictures Animation...   313522201
# 4     ['Studio 8', 'Solstice Productions', 'Ingeniou...           0
# ...                                                 ...         ...
# 9995                            ['Rajshri Productions']     4000000
# 9996       ['Universal Pictures', 'Aspen Film Society']    18196170
# 9997  ['The Picture Property Company', 'Allied Visio...     1919653
# 9998  ['Renn Productions', 'Timothy Burrill Producti...    20101247
# 9999           ['Quickfire Films', 'Gold Circle Films']     2405143
#
# [10000 rows x 7 columns]

# %%
merged_df = pd.merge(two_df, one_df, on="Movie Name", how="left")
merged_df
# Out:
#                                 Movie Name  \
# 0                                   Fast X
# 1                     John Wick: Chapter 4
# 2              The Super Mario Bros. Movie
# 3      Spider-Man: Across the Spider-Verse
# 4                                 Hypnotic
# ...                                    ...
# 10544                                Vivah
# 10545            Dead Men Don't Wear Plaid
# 10546                            Communion
# 10547                                 Tess
# 10548       The Possession of Michael King
#
#                                                   genres  vote_average  \
# 0                        ['Action', 'Crime', 'Thriller']           7.4
# 1                        ['Action', 'Thriller', 'Crime']           7.9
# 2      ['Animation', 'Family', 'Adventure', 'Fantasy'...           7.8
# 3      ['Action', 'Adventure', 'Animation', 'Science ...           8.8
# 4             ['Mystery', 'Thriller', 'Science Fiction']           6.5
# ...                                                  ...           ...
# 10544                               ['Romance', 'Drama']           6.4
# 10545                              ['Comedy', 'Mystery']           6.6
# 10546  ['Drama', 'Horror', 'Science Fiction', 'Thrill...           5.3
# 10547                               ['Drama', 'Romance']           7.0
# 10548                                         ['Horror']           6.1
#
#        vote_count     budget  \
# 0            1347  340000000
# 1            2896   90000000
# 2            4628  100000000
# 3            1160  100000000
# 4             154   70000000
# ...           ...        ...
# 10544          70          0
# 10545         324    9000000
# 10546         147    5000000
# 10547         283   12000000
# 10548         346          0
#
#                                     production_companies     revenue  \
# 0      ['Universal Pictures', 'Original Film', 'One R...   652000000
# 1      ['Thunder Road', '87Eleven', 'Summit Entertain...   431769198
# 2      ['Universal Pictures', 'Illumination', 'Ninten...  1308766975
# 3      ['Columbia Pictures', 'Sony Pictures Animation...   313522201
# 4      ['Studio 8', 'Solstice Productions', 'Ingeniou...           0
# ...                                                  ...         ...
# 10544                            ['Rajshri Productions']     4000000
# 10545       ['Universal Pictures', 'Aspen Film Society']    18196170
# 10546  ['The Picture Property Company', 'Allied Visio...     1919653
# 10547  ['Renn Productions', 'Timothy Burrill Producti...    20101247
# 10548           ['Quickfire Films', 'Gold Circle Films']     2405143
#
#        Year of Release  Movie Rating     Votes       Gross  \
# 0               2023.0           5.8   97114.0         NaN
# 1               2023.0           7.8  281426.0         NaN
# 2               2023.0           7.1  195626.0         NaN
# 3               2023.0           8.7  270500.0         NaN
# 4               2023.0           5.5   22509.0         NaN
# ...                ...           ...       ...         ...
# 10544           2006.0           6.6   10528.0         NaN
# 10545           1982.0           6.8   23129.0  18200000.0
# 10546              NaN           NaN       NaN         NaN
# 10547           1979.0           7.3   17743.0         NaN
# 10548           2014.0           5.7   13034.0         NaN
#
#                                         Genre Certification  \
# 0          ['Action', ' Adventure', ' Crime']         PG-13
# 1           ['Action', ' Crime', ' Thriller']             R
# 2      ['Animation', ' Adventure', ' Comedy']            PG
# 3      ['Animation', ' Action', ' Adventure']            PG
# 4         ['Action', ' Mystery', ' Thriller']             R
# ...                                       ...           ...
# 10544       ['Drama', ' Musical', ' Romance']     Not Rated
# 10545        ['Comedy', ' Crime', ' Mystery']            PG
# 10546                                     NaN           NaN
# 10547                   ['Drama', ' Romance']            PG
# 10548                              ['Horror']             R
#
#                                                 Director
# 0                                    ['Louis Leterrier']
# 1                                     ['Chad Stahelski']
# 2      ['Aaron Horvath', 'Michael Jelenic', 'Pierre L...
# 3      ['Joaquim Dos Santos', 'Kemp Powers', 'Justin ...
# 4                                   ['Robert Rodriguez']
# ...                                                  ...
# 10544                             ['Sooraj R. Barjatya']
# 10545                                    ['Carl Reiner']
# 10546                                                NaN
# 10547                                 ['Roman Polanski']
# 10548                                     ['David Jung']
#
# [10549 rows x 14 columns]

# %%
# Drop missing data
del merged_df["budget"]
clean_df = merged_df.dropna(how="any")
clean_df
# Out:
#                       Movie Name  \
# 8             The Little Mermaid
# 10      Avatar: The Way of Water
# 19          The Three Musketeers
# 20          The Three Musketeers
# 21          The Three Musketeers
# ...                          ...
# 10536             Les Misérables
# 10537             Les Misérables
# 10538                 15 Minutes
# 10539          Love & Basketball
# 10545  Dead Men Don't Wear Plaid
#
#                                               genres  vote_average  \
# 8      ['Adventure', 'Family', 'Fantasy', 'Romance']           6.2
# 10        ['Science Fiction', 'Adventure', 'Action']           7.7
# 19                           ['Action', 'Adventure']           5.4
# 20                           ['Action', 'Adventure']           5.4
# 21                           ['Action', 'Adventure']           5.4
# ...                                              ...           ...
# 10536       ['Crime', 'Drama', 'History', 'Romance']           7.2
# 10537       ['Crime', 'Drama', 'History', 'Romance']           7.2
# 10538                ['Action', 'Crime', 'Thriller']           5.9
# 10539                 ['Comedy', 'Drama', 'Romance']           7.5
# 10545                          ['Comedy', 'Mystery']           6.6
#
#        vote_count                               production_companies  \
# 8             616  ['Walt Disney Pictures', 'Lucamar Productions'...
# 10           8493  ['20th Century Studios', 'Lightstorm Entertain...
# 19             25                                                 []
# 20             25                                                 []
# 21             25                                                 []
# ...           ...                                                ...
# 10536         526                              ['Columbia Pictures']
# 10537         526                              ['Columbia Pictures']
# 10538         624  ['New Line Cinema', 'Industry Entertainment', ...
# 10539         383                  ['40 Acres and a Mule Filmworks']
# 10545         324       ['Universal Pictures', 'Aspen Film Society']
#
#           revenue  Year of Release  Movie Rating     Votes        Gross  \
# 8       414000000           1989.0           7.6  283516.0  111540000.0
# 10     2320250281           2022.0           7.6  461810.0  659680000.0
# 19              0           1973.0           7.1   19599.0   22020000.0
# 20              0           1993.0           6.4   57836.0   53900000.0
# 21              0           2011.0           5.7  110746.0   20380000.0
# ...           ...              ...           ...       ...          ...
# 10536    14096321           2012.0           7.5  340260.0  148810000.0
# 10537    14096321           1998.0           7.4   42543.0   14100000.0
# 10538    56359980           2001.0           6.1   51436.0   24400000.0
# 10539    27728118           2000.0           7.2   23318.0   27440000.0
# 10545    18196170           1982.0           6.8   23129.0   18200000.0
#
#                                         Genre Certification  \
# 8      ['Animation', ' Adventure', ' Family']             G
# 10       ['Action', ' Adventure', ' Fantasy']         PG-13
# 19       ['Action', ' Adventure', ' Romance']            PG
# 20       ['Action', ' Adventure', ' Romance']            PG
# 21       ['Action', ' Adventure', ' Fantasy']         PG-13
# ...                                       ...           ...
# 10536       ['Drama', ' Musical', ' Romance']         PG-13
# 10537         ['Crime', ' Drama', ' Romance']         PG-13
# 10538          ['Action', ' Crime', ' Drama']             R
# 10539         ['Drama', ' Romance', ' Sport']         PG-13
# 10545        ['Comedy', ' Crime', ' Mystery']            PG
#
#                               Director
# 8      ['Ron Clements', 'John Musker']
# 10                   ['James Cameron']
# 19                  ['Richard Lester']
# 20                   ['Stephen Herek']
# 21              ['Paul W.S. Anderson']
# ...                                ...
# 10536                   ['Tom Hooper']
# 10537                 ['Bille August']
# 10538                ['John Herzfeld']
# 10539        ['Gina Prince-Bythewood']
# 10545                  ['Carl Reiner']
#
# [4790 rows x 13 columns]

# %%
# Replace empty brackets
clean_df["production_companies"] = clean_df["production_companies"].replace({"[]": "*"})
clean_df.drop(clean_df[clean_df["production_companies"]=="*"].index)
clean_df
# Out:
# /var/folders/ry/_22269n950s4yfgx8rkg1p0m0000gn/T/ipykernel_65140/1712569316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["production_companies"] = clean_df["production_companies"].replace({"[]": "*"})
#                       Movie Name  \
# 8             The Little Mermaid
# 10      Avatar: The Way of Water
# 19          The Three Musketeers
# 20          The Three Musketeers
# 21          The Three Musketeers
# ...                          ...
# 10536             Les Misérables
# 10537             Les Misérables
# 10538                 15 Minutes
# 10539          Love & Basketball
# 10545  Dead Men Don't Wear Plaid
#
#                                               genres  vote_average  \
# 8      ['Adventure', 'Family', 'Fantasy', 'Romance']           6.2
# 10        ['Science Fiction', 'Adventure', 'Action']           7.7
# 19                           ['Action', 'Adventure']           5.4
# 20                           ['Action', 'Adventure']           5.4
# 21                           ['Action', 'Adventure']           5.4
# ...                                              ...           ...
# 10536       ['Crime', 'Drama', 'History', 'Romance']           7.2
# 10537       ['Crime', 'Drama', 'History', 'Romance']           7.2
# 10538                ['Action', 'Crime', 'Thriller']           5.9
# 10539                 ['Comedy', 'Drama', 'Romance']           7.5
# 10545                          ['Comedy', 'Mystery']           6.6
#
#        vote_count                               production_companies  \
# 8             616  ['Walt Disney Pictures', 'Lucamar Productions'...
# 10           8493  ['20th Century Studios', 'Lightstorm Entertain...
# 19             25                                                  *
# 20             25                                                  *
# 21             25                                                  *
# ...           ...                                                ...
# 10536         526                              ['Columbia Pictures']
# 10537         526                              ['Columbia Pictures']
# 10538         624  ['New Line Cinema', 'Industry Entertainment', ...
# 10539         383                  ['40 Acres and a Mule Filmworks']
# 10545         324       ['Universal Pictures', 'Aspen Film Society']
#
#           revenue  Year of Release  Movie Rating     Votes        Gross  \
# 8       414000000           1989.0           7.6  283516.0  111540000.0
# 10     2320250281           2022.0           7.6  461810.0  659680000.0
# 19              0           1973.0           7.1   19599.0   22020000.0
# 20              0           1993.0           6.4   57836.0   53900000.0
# 21              0           2011.0           5.7  110746.0   20380000.0
# ...           ...              ...           ...       ...          ...
# 10536    14096321           2012.0           7.5  340260.0  148810000.0
# 10537    14096321           1998.0           7.4   42543.0   14100000.0
# 10538    56359980           2001.0           6.1   51436.0   24400000.0
# 10539    27728118           2000.0           7.2   23318.0   27440000.0
# 10545    18196170           1982.0           6.8   23129.0   18200000.0
#
#                                         Genre Certification  \
# 8      ['Animation', ' Adventure', ' Family']             G
# 10       ['Action', ' Adventure', ' Fantasy']         PG-13
# 19       ['Action', ' Adventure', ' Romance']            PG
# 20       ['Action', ' Adventure', ' Romance']            PG
# 21       ['Action', ' Adventure', ' Fantasy']         PG-13
# ...                                       ...           ...
# 10536       ['Drama', ' Musical', ' Romance']         PG-13
# 10537         ['Crime', ' Drama', ' Romance']         PG-13
# 10538          ['Action', ' Crime', ' Drama']             R
# 10539         ['Drama', ' Romance', ' Sport']         PG-13
# 10545        ['Comedy', ' Crime', ' Mystery']            PG
#
#                               Director
# 8      ['Ron Clements', 'John Musker']
# 10                   ['James Cameron']
# 19                  ['Richard Lester']
# 20                   ['Stephen Herek']
# 21              ['Paul W.S. Anderson']
# ...                                ...
# 10536                   ['Tom Hooper']
# 10537                 ['Bille August']
# 10538                ['John Herzfeld']
# 10539        ['Gina Prince-Bythewood']
# 10545                  ['Carl Reiner']
#
# [4790 rows x 13 columns]

# %%
clean_df = clean_df.rename(columns={"vote_average": "Vote Average",
                                   "vote_count": "Vote Count",
                                   "production_companies": "Production Companies",
                                   "revenue": "Revenue"})

clean_df
# Out:
#                               Movie Name  \
# 8                     The Little Mermaid
# 10              Avatar: The Way of Water
# 19                  The Three Musketeers
# 23                          Mother's Day
# 29     Spider-Man: Into the Spider-Verse
# ...                                  ...
# 10532                  The Mark of Zorro
# 10534                                 54
# 10538                         15 Minutes
# 10539                  Love & Basketball
# 10545          Dead Men Don't Wear Plaid
#
#                                                   genres  vote_average  \
# 8          ['Adventure', 'Family', 'Fantasy', 'Romance']           6.2
# 10            ['Science Fiction', 'Adventure', 'Action']           7.7
# 19                               ['Action', 'Adventure']           5.4
# 23                       ['Thriller', 'Drama', 'Action']           6.0
# 29     ['Action', 'Adventure', 'Animation', 'Science ...           8.4
# ...                                                  ...           ...
# 10532        ['Action', 'Adventure', 'Drama', 'Romance']           7.1
# 10534                                 ['Drama', 'Music']           5.8
# 10538                    ['Action', 'Crime', 'Thriller']           5.9
# 10539                     ['Comedy', 'Drama', 'Romance']           7.5
# 10545                              ['Comedy', 'Mystery']           6.6
#
#        vote_count                               production_companies  \
# 8             616  ['Walt Disney Pictures', 'Lucamar Productions'...
# 10           8493  ['20th Century Studios', 'Lightstorm Entertain...
# 19             25                                                  *
# 23             94                                   ['Akson Studio']
# 29          13081  ['Columbia Pictures', 'Lord Miller', 'Pascal P...
# ...           ...                                                ...
# 10532         174                               ['20th Century Fox']
# 10534         422  ['Dollface', 'Redeemable Features', 'FilmColon...
# 10538         624  ['New Line Cinema', 'Industry Entertainment', ...
# 10539         383                  ['40 Acres and a Mule Filmworks']
# 10545         324       ['Universal Pictures', 'Aspen Film Society']
#
#           revenue  Year of Release  Movie Rating     Votes        Gross  \
# 8       414000000           1989.0           7.6  283516.0  111540000.0
# 10     2320250281           2022.0           7.6  461810.0  659680000.0
# 19              0           1973.0           7.1   19599.0   22020000.0
# 23              0           2016.0           5.6   38894.0   32460000.0
# 29      375464627           2018.0           8.4  632177.0  190240000.0
# ...           ...              ...           ...       ...          ...
# 10532           0           1940.0           7.5   10674.0    4360000.0
# 10534    16757163           1998.0           5.9   34130.0   16570000.0
# 10538    56359980           2001.0           6.1   51436.0   24400000.0
# 10539    27728118           2000.0           7.2   23318.0   27440000.0
# 10545    18196170           1982.0           6.8   23129.0   18200000.0
#
#                                         Genre Certification  \
# 8      ['Animation', ' Adventure', ' Family']             G
# 10       ['Action', ' Adventure', ' Fantasy']         PG-13
# 19       ['Action', ' Adventure', ' Romance']            PG
# 23           ['Comedy', ' Drama', ' Romance']         PG-13
# 29     ['Animation', ' Action', ' Adventure']            PG
# ...                                       ...           ...
# 10532     ['Action', ' Adventure', ' Family']      Approved
# 10534                     ['Drama', ' Music']             R
# 10538          ['Action', ' Crime', ' Drama']             R
# 10539         ['Drama', ' Romance', ' Sport']         PG-13
# 10545        ['Comedy', ' Crime', ' Mystery']            PG
#
#                                                 Director
# 8                        ['Ron Clements', 'John Musker']
# 10                                     ['James Cameron']
# 19                                    ['Richard Lester']
# 23                                    ['Garry Marshall']
# 29     ['Bob Persichetti', 'Peter Ramsey', 'Rodney Ro...
# ...                                                  ...
# 10532                               ['Rouben Mamoulian']
# 10534                               ['Mark Christopher']
# 10538                                  ['John Herzfeld']
# 10539                          ['Gina Prince-Bythewood']
# 10545                                    ['Carl Reiner']
#
# [4200 rows x 13 columns]

# %%
clean_df = clean_df.rename(columns={"vote_average": "Vote Average",
                                   "vote_count": "Vote Count",
                                   "production_companies": "Production Companies",
                                   "revenue": "Revenue"})
del clean_df["Genres"]
clean_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       1 clean_df = clean_df.rename(columns={"vote_average": "Vote Average",
#       2                                    "vote_count": "Vote Count",
#       3                                    "production_companies": "Production Companies",
#       4                                    "revenue": "Revenue"})
# ----> 5 del clean_df["Genres"]
#       6 clean_df
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:4279, in NDFrame.__delitem__(self, key)
#    4274             deleted = True
#    4275 if not deleted:
#    4276     # If the above loop ran and didn't delete anything because
#    4277     # there was no match, this call should raise the appropriate
#    4278     # exception:
# -> 4279     loc = self.axes[-1].get_loc(key)
#    4280     self._mgr = self._mgr.idelete(loc)
#    4282 # delete from the caches
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Genres'

# %%
# Save csv file
clean_df.to_csv("Datasets/clean_data.csv", index=False, header=True)

# %%
clean_data = Path("Datasets/clean_data.csv")
clean_data_df = pd.read_csv(clean_data)
clean_data_df
# Out:
#                              Movie Name  Vote Average  Vote Count  \
# 0                    The Little Mermaid           6.2         616
# 1              Avatar: The Way of Water           7.7        8493
# 2                  The Three Musketeers           5.4          25
# 3                          Mother's Day           6.0          94
# 4     Spider-Man: Into the Spider-Verse           8.4       13081
# ...                                 ...           ...         ...
# 4195                  The Mark of Zorro           7.1         174
# 4196                                 54           5.8         422
# 4197                         15 Minutes           5.9         624
# 4198                  Love & Basketball           7.5         383
# 4199          Dead Men Don't Wear Plaid           6.6         324
#
#                                    Production Companies     Revenue  \
# 0     ['Walt Disney Pictures', 'Lucamar Productions'...   414000000
# 1     ['20th Century Studios', 'Lightstorm Entertain...  2320250281
# 2                                                     *           0
# 3                                      ['Akson Studio']           0
# 4     ['Columbia Pictures', 'Lord Miller', 'Pascal P...   375464627
# ...                                                 ...         ...
# 4195                               ['20th Century Fox']           0
# 4196  ['Dollface', 'Redeemable Features', 'FilmColon...    16757163
# 4197  ['New Line Cinema', 'Industry Entertainment', ...    56359980
# 4198                  ['40 Acres and a Mule Filmworks']    27728118
# 4199       ['Universal Pictures', 'Aspen Film Society']    18196170
#
#       Year of Release  Movie Rating     Votes        Gross  \
# 0              1989.0           7.6  283516.0  111540000.0
# 1              2022.0           7.6  461810.0  659680000.0
# 2              1973.0           7.1   19599.0   22020000.0
# 3              2016.0           5.6   38894.0   32460000.0
# 4              2018.0           8.4  632177.0  190240000.0
# ...               ...           ...       ...          ...
# 4195           1940.0           7.5   10674.0    4360000.0
# 4196           1998.0           5.9   34130.0   16570000.0
# 4197           2001.0           6.1   51436.0   24400000.0
# 4198           2000.0           7.2   23318.0   27440000.0
# 4199           1982.0           6.8   23129.0   18200000.0
#
#                                        Genre Certification  \
# 0     ['Animation', ' Adventure', ' Family']             G
# 1       ['Action', ' Adventure', ' Fantasy']         PG-13
# 2       ['Action', ' Adventure', ' Romance']            PG
# 3           ['Comedy', ' Drama', ' Romance']         PG-13
# 4     ['Animation', ' Action', ' Adventure']            PG
# ...                                      ...           ...
# 4195     ['Action', ' Adventure', ' Family']      Approved
# 4196                     ['Drama', ' Music']             R
# 4197          ['Action', ' Crime', ' Drama']             R
# 4198         ['Drama', ' Romance', ' Sport']         PG-13
# 4199        ['Comedy', ' Crime', ' Mystery']            PG
#
#                                                Director
# 0                       ['Ron Clements', 'John Musker']
# 1                                     ['James Cameron']
# 2                                    ['Richard Lester']
# 3                                    ['Garry Marshall']
# 4     ['Bob Persichetti', 'Peter Ramsey', 'Rodney Ro...
# ...                                                 ...
# 4195                               ['Rouben Mamoulian']
# 4196                               ['Mark Christopher']
# 4197                                  ['John Herzfeld']
# 4198                          ['Gina Prince-Bythewood']
# 4199                                    ['Carl Reiner']
#
# [4200 rows x 12 columns]

# %%
filtered_df = clean_data_df.loc[(clean_data_df['Year of Release'] > 2009)
                     & (clean_data_df['Year of Release'] < 2020)]
filtered_df
# Out:
#                              Movie Name  Vote Average  Vote Count  \
# 3                          Mother's Day           6.0          94
# 4     Spider-Man: Into the Spider-Verse           8.4       13081
# 8       Transformers: Age of Extinction           5.9        7359
# 12        Transformers: The Last Knight           6.1        5548
# 20       Guardians of the Galaxy Vol. 2           7.6       19898
# ...                                 ...           ...         ...
# 4185                         The Butler           7.3        2692
# 4186                          High-Rise           5.7        1038
# 4189              The Birth of a Nation           6.1         468
# 4190                         Little Boy           7.2         485
# 4191                          Happy End           6.6          53
#
#                                    Production Companies     Revenue  \
# 3                                      ['Akson Studio']           0
# 4     ['Columbia Pictures', 'Lord Miller', 'Pascal P...   375464627
# 8     ['di Bonaventura Pictures', 'Tom DeSanto/Don M...  1104054072
# 12    ['Paramount', 'di Bonaventura Pictures', 'Ian ...   605425157
# 20                                   ['Marvel Studios']   863756051
# ...                                                 ...         ...
# 4185  ['Follow Through Productions', 'Salamander Pic...   115922175
# 4186  ['HanWay Films', 'SCOPE Pictures', 'Recorded P...      346472
# 4189                                 ['Epoch Film Co.']    11000000
# 4190               ['Santa Fé Films', 'Metanoia Films']     6485961
# 4191                ['Myung Films', 'CJ Entertainment']           0
#
#       Year of Release  Movie Rating     Votes        Gross  \
# 3              2016.0           5.6   38894.0   32460000.0
# 4              2018.0           8.4  632177.0  190240000.0
# 8              2014.0           5.6  326960.0  245440000.0
# 12             2017.0           5.2  164230.0  130170000.0
# 20             2017.0           7.6  736895.0  389810000.0
# ...               ...           ...       ...          ...
# 4185           2013.0           7.2  118325.0  116630000.0
# 4186           2015.0           5.5   44402.0     340000.0
# 4189           2016.0           6.5   21628.0   15860000.0
# 4190           2015.0           7.3   23885.0    6420000.0
# 4191           2017.0           6.6   16507.0     300000.0
#
#                                        Genre Certification  \
# 3           ['Comedy', ' Drama', ' Romance']         PG-13
# 4     ['Animation', ' Action', ' Adventure']            PG
# 8        ['Action', ' Adventure', ' Sci-Fi']         PG-13
# 12       ['Action', ' Adventure', ' Sci-Fi']         PG-13
# 20       ['Action', ' Adventure', ' Comedy']         PG-13
# ...                                      ...           ...
# 4185                 ['Biography', ' Drama']         PG-13
# 4186                    ['Drama', ' Sci-Fi']             R
# 4189     ['Biography', ' Drama', ' History']             R
# 4190           ['Drama', ' History', ' War']         PG-13
# 4191                               ['Drama']             R
#
#                                                Director
# 3                                    ['Garry Marshall']
# 4     ['Bob Persichetti', 'Peter Ramsey', 'Rodney Ro...
# 8                                       ['Michael Bay']
# 12                                      ['Michael Bay']
# 20                                       ['James Gunn']
# ...                                                 ...
# 4185                                    ['Lee Daniels']
# 4186                                   ['Ben Wheatley']
# 4189                                    ['Nate Parker']
# 4190                           ['Alejandro Monteverde']
# 4191                                 ['Michael Haneke']
#
# [1384 rows x 12 columns]

# %%
# Save filtered csv file
filtered_df.to_csv("Datasets/filtered_data.csv", index=False, header=True)
